# %% [markdown]
# <a href="https://colab.research.google.com/github/Pakhi27/Named-Entity-Recognition-NLP-/blob/main/Named_Entity_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Named Entity Recognition(NER)

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipe_names
# ent-entity
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp("Tesla Inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to acquire twitter for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </div></span>

# %% [markdown]
# List down all the entities

# %%
nlp.pipe_labels['ner']
# Out:
# ['CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART']

# %%
doc = nlp("Michael Bloomberg founded Bloomberg in 1982")
for ent in doc.ents:
    print(ent.text, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Michael Bloomberg | PERSON | People, including fictional
# Bloomberg | PERSON | People, including fictional
# 1982 | DATE | Absolute or relative dates or periods

# %%
doc = nlp("Michael Bloomberg founded Bloomberg in 1982")
for ent in doc.ents:
    print(ent.text, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# Michael Bloomberg | PERSON | People, including fictional
# Bloomberg | PERSON | People, including fictional
# 1982 | DATE | Absolute or relative dates or periods

# %%
doc = nlp("Tesla Inc is going to acquire Twitter Inc for $45 billion")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", ent.start_char, "|", ent.end_char)
# Out:
# Tesla Inc  |  ORG  |  0 | 9
# Twitter Inc  |  ORG  |  30 | 41
# $45 billion  |  MONEY  |  46 | 57

# %% [markdown]
# Setting custom entities

# %%
doc = nlp("Tesla is going to acquire Twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, " | ", ent.label_)
# Out:
# Tesla  |  ORG
# Twitter  |  PRODUCT
# $45 billion  |  MONEY

# %%
s = doc[2:5]
s
# span of tokens
# Out:
# going to acquire

# %%
type(s)
# Out:
# spacy.tokens.span.Span

# %%
from spacy.tokens import Span

# tesla
s1 = Span(doc, 0, 1, label="ORG")
# twitter
s2 = Span(doc, 5, 6, label="ORG")

doc.set_ents([s1, s2], default="unmodified")

# %%
for ent in doc.ents:
    print(ent.text, " | ", ent.label_)
# Out:
# Tesla  |  ORG
# Twitter  |  ORG
# $45 billion  |  MONEY

# %% [markdown]
# NER using Hugging Face

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = "My name is Wolfgang and I live in Berlin"

ner_results = nlp(example)
print(ner_results)
# The output is a list of dictionaries, each representing a named entity identified in the text.
# Each dictionary contains the following information:
# entity: The entity type (e.g., "B-PER" for person, "B-LOC" for location).
# score: The confidence score associated with the entity prediction.
# index: The index of the token in the input sequence.
# word: The actual word identified as the entity.
# start: The starting index of the entity in the input text.
# end: The ending index of the entity in the input text.
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'entity': 'B-PER', 'score': 0.9990139, 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': 0.999645, 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %% [markdown]
# NER Dataset using BERT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/NER dataset.csv', encoding='latin-1')  # Replace 'latin-1' with the appropriate encoding

# %%
dataset=pd.DataFrame(df)

# %%
df.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
df=df.drop('Sentence #',axis=1)

# %%
df.tail()
# Out:
#               Word  POS Tag
# 1048570       they  PRP   O
# 1048571  responded  VBD   O
# 1048572         to   TO   O
# 1048573        the   DT   O
# 1048574     attack   NN   O

# %%
df.columns
# Out:
# Index(['Word', 'POS', 'Tag'], dtype='object')

# %%
df.tail()
# Out:
#               Word  POS Tag
# 1048570       they  PRP   O
# 1048571  responded  VBD   O
# 1048572         to   TO   O
# 1048573        the   DT   O
# 1048574     attack   NN   O

# %%
df
# Out:
#                   Word  POS Tag
# 0            Thousands  NNS   O
# 1                   of   IN   O
# 2        demonstrators  NNS   O
# 3                 have  VBP   O
# 4              marched  VBN   O
# ...                ...  ...  ..
# 1048570           they  PRP   O
# 1048571      responded  VBD   O
# 1048572             to   TO   O
# 1048573            the   DT   O
# 1048574         attack   NN   O
#
# [1048575 rows x 3 columns]

# %%
sample_size = 1000
df = df.sample(n=sample_size)

# %%
df
# Out:
#              Word  POS Tag
# 934584         an   DT   O
# 807422     threat   NN   O
# 395773          ,    ,   O
# 371634  operation   NN   O
# 880575        3.5   CD   O
# ...           ...  ...  ..
# 909540    intends  VBZ   O
# 651786         of   IN   O
# 992446          "   ``   O
# 329084       five   CD   O
# 154793          A   DT   O
#
# [1000 rows x 3 columns]

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
ner_results = []
for text in df['Word']:
    results = nlp(text)
    ner_results.append(results)

# %%
# Assuming your dataset has a column named 'text'
for index, row in df.iterrows():
    text = row['Word']
    results = nlp(text)
    print(f"For text: {text}")
    print(results)
# Out:
# For text: an
# []
# For text: threat
# []
# For text: ,
# []
# For text: operation
# []
# For text: 3.5
# []
# For text: States
# [{'entity': 'B-LOC', 'score': 0.9986577, 'index': 1, 'word': 'States', 'start': 0, 'end': 6}]
# For text: Dogg
# []
# For text: bribery
# []
# For text: ,
# []
# For text: of
# []
# For text: to
# []
# For text: sovereignty
# []
# For text: Saberi
# [{'entity': 'B-PER', 'score': 0.64173347, 'index': 1, 'word': 'Sa', 'start': 0, 'end': 2}, {'entity': 'I-ORG', 'score': 0.63520426, 'index': 2, 'word': '##ber', 'start': 2, 'end': 5}]
# For text: But
# []
# For text: and
# []
# For text: the
# []
# For text: was
# []
# For text: occurs
# []
# For text: United
# [{'entity': 'B-ORG', 'score': 0.99877137, 'index': 1, 'word': 'United', 'start': 0, 'end': 6}]
# For text: nation
# []
# For text: in
# []
# For text: show
# []
# For text: .
# []
# For text: hostages
# []
# For text: .
# []
# For text: founded
# []
# For text: VOA
# [{'entity': 'B-ORG', 'score': 0.9989691, 'index': 1, 'word': 'V', 'start': 0, 'end': 1}, {'entity': 'I-ORG', 'score': 0.9898385, 'index': 2, 'word': '##OA', 'start': 1, 'end': 3}]
# For text: .
# []
# For text: narrowly
# []
# For text: the
# []
# For text: partnership
# []
# For text: Pakistan
# [{'entity': 'B-LOC', 'score': 0.9998098, 'index': 1, 'word': 'Pakistan', 'start': 0, 'end': 8}]
# For text: that
# []
# For text: North
# [{'entity': 'B-LOC', 'score': 0.9969271, 'index': 1, 'word': 'North', 'start': 0, 'end': 5}]
# For text: the
# []
# For text: the
# []
# For text: to
# []
# For text: a
# []
# For text: the
# []
# For text: Under
# []
# For text: a
# []
# For text: Spin
# [{'entity': 'B-MISC', 'score': 0.8641482, 'index': 1, 'word': 'Spin', 'start': 0, 'end': 4}]
# For text: .
# []
# For text: acknowledges
# []
# For text: fighters
# []
# For text: Kim
# [{'entity': 'B-PER', 'score': 0.99953175, 'index': 1, 'word': 'Kim', 'start': 0, 'end': 3}]
# For text: Russian
# [{'entity': 'B-MISC', 'score': 0.9995314, 'index': 1, 'word': 'Russian', 'start': 0, 'end': 7}]
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: virus
# []
# For text: .
# []
# For text: told
# []
# For text: in
# []
# For text: around
# []
# For text: member
# []
# For text: Iran
# [{'entity': 'B-LOC', 'score': 0.99983764, 'index': 1, 'word': 'Iran', 'start': 0, 'end': 4}]
# For text: The
# []
# For text: until
# []
# For text: the
# []
# For text: positively
# []
# For text: goal
# []
# For text: in
# []
# For text: merriment
# []
# For text: A
# []
# For text: .
# []
# For text: killed
# []
# For text: is
# []
# For text: post
# []
# For text: revolt
# []
# For text: envoy
# []
# For text: took
# []
# For text: ,
# []
# For text: registering
# []
# For text: Afghanistan
# [{'entity': 'B-LOC', 'score': 0.99980897, 'index': 1, 'word': 'Afghanistan', 'start': 0, 'end': 11}]
# For text: .
# []
# For text: of
# []
# For text: Fiji
# [{'entity': 'B-LOC', 'score': 0.9998142, 'index': 1, 'word': 'Fiji', 'start': 0, 'end': 4}]
# For text: to
# []
# For text: patrol
# []
# For text: Haiti
# [{'entity': 'B-LOC', 'score': 0.9998037, 'index': 1, 'word': 'Haiti', 'start': 0, 'end': 5}]
# For text: irregularities
# []
# For text: rise
# []
# For text: The
# []
# For text: his
# []
# For text: tape
# []
# For text: will
# []
# For text: whether
# []
# For text: efforts
# []
# For text: most
# []
# For text: a
# []
# For text: took
# []
# For text: observances
# []
# For text: Monaco
# [{'entity': 'B-LOC', 'score': 0.69703674, 'index': 1, 'word': 'Monaco', 'start': 0, 'end': 6}]
# For text: A
# []
# For text: been
# []
# For text: of
# []
# For text: Province
# [{'entity': 'B-ORG', 'score': 0.67575294, 'index': 1, 'word': 'Province', 'start': 0, 'end': 8}]
# For text: ,
# []
# For text: Iran
# [{'entity': 'B-LOC', 'score': 0.99983764, 'index': 1, 'word': 'Iran', 'start': 0, 'end': 4}]
# For text: city
# []
# For text: Russian
# [{'entity': 'B-MISC', 'score': 0.9995314, 'index': 1, 'word': 'Russian', 'start': 0, 'end': 7}]
# For text: except
# []
# For text: were
# []
# For text: Press
# []
# For text: Bush
# [{'entity': 'B-PER', 'score': 0.99541485, 'index': 1, 'word': 'Bush', 'start': 0, 'end': 4}]
# For text: where
# []
# For text: taking
# []
# For text: "
# []
# For text: Taliban
# [{'entity': 'B-ORG', 'score': 0.9003508, 'index': 1, 'word': 'Taliban', 'start': 0, 'end': 7}]
# For text: recently
# []
# For text: will
# []
# For text: gathered
# []
# For text: struggled
# []
# For text: Annan
# [{'entity': 'B-ORG', 'score': 0.98712695, 'index': 1, 'word': 'Anna', 'start': 0, 'end': 4}, {'entity': 'I-ORG', 'score': 0.594081, 'index': 2, 'word': '##n', 'start': 4, 'end': 5}]
# For text: until
# []
# For text: elections
# []
# For text: coup
# []
# For text: He
# []
# For text: the
# []
# For text: Tuesday
# []
# For text: with
# []
# For text: the
# []
# For text: the
# []
# For text: battle
# []
# For text: officials
# []
# For text: Prize
# []
# For text: Bush
# [{'entity': 'B-PER', 'score': 0.99541485, 'index': 1, 'word': 'Bush', 'start': 0, 'end': 4}]
# For text: that
# []
# For text: in
# []
# For text: .
# []
# For text: say
# []
# For text: as
# []
# For text: be
# []
# For text: Peace
# []
# For text: .
# []
# For text: in
# []
# For text: ,
# []
# For text: longer
# []
# For text: ,
# []
# For text: three
# []
# For text: Montenegro
# [{'entity': 'B-LOC', 'score': 0.999814, 'index': 1, 'word': 'Montenegro', 'start': 0, 'end': 10}]
# For text: ,
# []
# For text: one
# []
# For text: of
# []
# For text: the
# []
# For text: more
# []
# For text: ,
# []
# For text: member
# []
# For text: ,
# []
# For text: Organization
# [{'entity': 'B-ORG', 'score': 0.9199289, 'index': 1, 'word': 'Organization', 'start': 0, 'end': 12}]
# For text: The
# []
# For text: and
# []
# For text: ,
# []
# For text: of
# []
# For text: between
# []
# For text: two
# []
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: villages
# []
# For text: 2004
# []
# For text: a
# []
# For text: were
# []
# For text: the
# []
# For text: be
# []
# For text: holiday
# []
# For text: ,
# []
# For text: Canada
# [{'entity': 'B-LOC', 'score': 0.99981195, 'index': 1, 'word': 'Canada', 'start': 0, 'end': 6}]
# For text: her
# []
# For text: government
# []
# For text: the
# []
# For text: 's
# []
# For text: peace
# []
# For text: of
# []
# For text: Taleban
# [{'entity': 'B-MISC', 'score': 0.99829036, 'index': 1, 'word': 'Tale', 'start': 0, 'end': 4}, {'entity': 'I-MISC', 'score': 0.97330654, 'index': 2, 'word': '##ban', 'start': 4, 'end': 7}]
# For text: they
# []
# For text: money
# []
# For text: this
# []
# For text: ,
# []
# For text: oversight
# []
# For text: handovers
# []
# For text: and
# []
# For text: has
# []
# For text: be
# []
# For text: southern
# []
# For text: announced
# []
# For text: for
# []
# For text: 1976
# []
# For text: to
# []
# For text: Senators
# [{'entity': 'B-MISC', 'score': 0.84541583, 'index': 1, 'word': 'Senators', 'start': 0, 'end': 8}]
# For text: the
# []
# For text: she
# []
# For text: of
# []
# For text: unless
# []
# For text: Violence
# []
# For text: .
# []
# For text: his
# []
# For text: .
# []
# For text: Iraq
# [{'entity': 'B-LOC', 'score': 0.99984574, 'index': 1, 'word': 'Iraq', 'start': 0, 'end': 4}]
# For text: incident
# []
# For text: the
# []
# For text: possible
# []
# For text: the
# []
# For text: base
# []
# For text: .
# []
# For text: he
# []
# For text: who
# []
# For text: stung
# []
# For text: stop
# []
# For text: that
# []
# For text: the
# []
# For text: impoverished
# []
# For text: reduced
# []
# For text: diplomatic
# []
# For text: in
# []
# For text: currently
# []
# For text: is
# []
# For text: of
# []
# For text: which
# []
# For text: church
# []
# For text: wounded
# []
# For text: overcome
# []
# For text: not
# []
# For text: the
# []
# For text: .
# []
# For text: seized
# []
# For text: one
# []
# For text: .
# []
# For text: committee
# []
# For text: and
# []
# For text: have
# []
# For text: .
# []
# For text: a
# []
# For text: in
# []
# For text: approval
# []
# For text: official
# []
# For text: On
# []
# For text: way
# []
# For text: China
# [{'entity': 'B-LOC', 'score': 0.99985445, 'index': 1, 'word': 'China', 'start': 0, 'end': 5}]
# For text: one
# []
# For text: during
# []
# For text: European
# [{'entity': 'B-MISC', 'score': 0.9995665, 'index': 1, 'word': 'European', 'start': 0, 'end': 8}]
# For text: turned
# []
# For text: Talbak
# [{'entity': 'B-ORG', 'score': 0.9981969, 'index': 1, 'word': 'Ta', 'start': 0, 'end': 2}, {'entity': 'I-ORG', 'score': 0.70330155, 'index': 2, 'word': '##l', 'start': 2, 'end': 3}, {'entity': 'I-ORG', 'score': 0.9975764, 'index': 3, 'word': '##ba', 'start': 3, 'end': 5}, {'entity': 'I-ORG', 'score': 0.99358714, 'index': 4, 'word': '##k', 'start': 5, 'end': 6}]
# For text: Lieberman
# [{'entity': 'B-PER', 'score': 0.9873706, 'index': 1, 'word': 'Lie', 'start': 0, 'end': 3}, {'entity': 'B-PER', 'score': 0.40779915, 'index': 2, 'word': '##berman', 'start': 3, 'end': 9}]
# For text: birds
# []
# For text: troop
# []
# For text: Dalai
# [{'entity': 'B-PER', 'score': 0.9975962, 'index': 1, 'word': 'Dal', 'start': 0, 'end': 3}, {'entity': 'I-PER', 'score': 0.41465124, 'index': 2, 'word': '##ai', 'start': 3, 'end': 5}]
# For text: the
# []
# For text: civil
# []
# For text: German
# [{'entity': 'B-MISC', 'score': 0.999592, 'index': 1, 'word': 'German', 'start': 0, 'end': 6}]
# For text: .
# []
# For text: Ismail
# [{'entity': 'B-PER', 'score': 0.99918324, 'index': 1, 'word': 'Ismail', 'start': 0, 'end': 6}]
# For text: approval
# []
# For text: require
# []
# For text: Sheik
# [{'entity': 'B-PER', 'score': 0.99939275, 'index': 1, 'word': 'She', 'start': 0, 'end': 3}, {'entity': 'B-PER', 'score': 0.9070734, 'index': 2, 'word': '##ik', 'start': 3, 'end': 5}]
# For text: North
# [{'entity': 'B-LOC', 'score': 0.9969271, 'index': 1, 'word': 'North', 'start': 0, 'end': 5}]
# For text: steep
# []
# For text: in
# []
# For text: Ebola
# [{'entity': 'B-MISC', 'score': 0.82822776, 'index': 1, 'word': 'E', 'start': 0, 'end': 1}, {'entity': 'I-MISC', 'score': 0.8550478, 'index': 3, 'word': '##a', 'start': 4, 'end': 5}]
# For text: enemy
# []
# For text: to
# []
# For text: has
# []
# For text: ,
# []
# For text: .
# []
# For text: the
# []
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: monarch
# []
# For text: released
# []
# For text: .
# []
# For text: nearly
# []
# For text: he
# []
# For text: States
# [{'entity': 'B-LOC', 'score': 0.9986577, 'index': 1, 'word': 'States', 'start': 0, 'end': 6}]
# For text: huts
# []
# For text: .
# []
# For text: patients
# []
# For text: that
# []
# For text: policy
# []
# For text: innocent
# []
# For text: Bennett
# [{'entity': 'B-PER', 'score': 0.99864846, 'index': 1, 'word': 'Bennett', 'start': 0, 'end': 7}]
# For text: ago
# []
# For text: called
# []
# For text: economist
# []
# For text: of
# []
# For text: missing
# []
# For text: of
# []
# For text: Caracas
# [{'entity': 'B-LOC', 'score': 0.9968747, 'index': 1, 'word': 'Caracas', 'start': 0, 'end': 7}]
# For text: military
# []
# For text: 's
# []
# For text: the
# []
# For text: than
# []
# For text: damage
# []
# For text: they
# []
# For text: senior
# []
# For text: China
# [{'entity': 'B-LOC', 'score': 0.99985445, 'index': 1, 'word': 'China', 'start': 0, 'end': 5}]
# For text: between
# []
# For text: that
# []
# For text: for
# []
# For text: at
# []
# For text: the
# []
# For text: Sattar
# [{'entity': 'B-PER', 'score': 0.99873215, 'index': 1, 'word': 'Sa', 'start': 0, 'end': 2}, {'entity': 'B-PER', 'score': 0.5488878, 'index': 2, 'word': '##tta', 'start': 2, 'end': 5}, {'entity': 'B-PER', 'score': 0.8541206, 'index': 3, 'word': '##r', 'start': 5, 'end': 6}]
# For text: area
# []
# For text: the
# []
# For text: are
# []
# For text: Sudan
# [{'entity': 'B-LOC', 'score': 0.9998043, 'index': 1, 'word': 'Sudan', 'start': 0, 'end': 5}]
# For text: of
# []
# For text: Gaza
# [{'entity': 'B-LOC', 'score': 0.99978024, 'index': 1, 'word': 'Gaza', 'start': 0, 'end': 4}]
# For text: Yes
# []
# For text: The
# []
# For text: oil
# []
# For text: help
# []
# For text: of
# []
# For text: said
# []
# For text: agency
# []
# For text: the
# []
# For text: rebels
# []
# For text: of
# []
# For text: the
# []
# For text: like
# []
# For text: reporters
# []
# For text: and
# []
# For text: South
# [{'entity': 'B-LOC', 'score': 0.99938977, 'index': 1, 'word': 'South', 'start': 0, 'end': 5}]
# For text: a
# []
# For text: downtown
# []
# For text: But
# []
# For text: Her
# []
# For text: strike
# []
# For text: top-level
# []
# For text: after
# []
# For text: Iraqi
# [{'entity': 'B-MISC', 'score': 0.9995493, 'index': 1, 'word': 'Iraqi', 'start': 0, 'end': 5}]
# For text: to
# []
# For text: year
# []
# For text: significantly
# []
# For text: across
# []
# For text: lack
# []
# For text: has
# []
# For text: officials
# []
# For text: for
# []
# For text: include
# []
# For text: keep
# []
# For text: normally
# []
# For text: yet
# []
# For text: World
# [{'entity': 'B-MISC', 'score': 0.56974983, 'index': 1, 'word': 'World', 'start': 0, 'end': 5}]
# For text: Korean
# [{'entity': 'B-MISC', 'score': 0.99864954, 'index': 1, 'word': 'Korean', 'start': 0, 'end': 6}]
# For text: in
# []
# For text: the
# []
# For text: denounce
# []
# For text: .
# []
# For text: .
# []
# For text: Serb
# [{'entity': 'B-MISC', 'score': 0.9996051, 'index': 1, 'word': 'Serb', 'start': 0, 'end': 4}]
# For text: policemen
# []
# For text: The
# []
# For text: in
# []
# For text: Andry
# [{'entity': 'B-PER', 'score': 0.99904734, 'index': 1, 'word': 'And', 'start': 0, 'end': 3}, {'entity': 'B-PER', 'score': 0.9320858, 'index': 2, 'word': '##ry', 'start': 3, 'end': 5}]
# For text: of
# []
# For text: years
# []
# For text: at
# []
# For text: supported
# []
# For text: peace
# []
# For text: and
# []
# For text: reforms
# []
# For text: Andy
# [{'entity': 'B-PER', 'score': 0.9960194, 'index': 1, 'word': 'Andy', 'start': 0, 'end': 4}]
# For text: Pakistani
# [{'entity': 'B-MISC', 'score': 0.9994629, 'index': 1, 'word': 'Pakistani', 'start': 0, 'end': 9}]
# For text: and
# []
# For text: in
# []
# For text: that
# []
# For text: an
# []
# For text: German
# [{'entity': 'B-MISC', 'score': 0.999592, 'index': 1, 'word': 'German', 'start': 0, 'end': 6}]
# For text: reached
# []
# For text: that
# []
# For text: a
# []
# For text: The
# []
# For text: city
# []
# For text: militant
# []
# For text: not
# []
# For text: it
# []
# For text: tested
# []
# For text: suggested
# []
# For text: .
# []
# For text: militant
# []
# For text: the
# []
# For text: state
# []
# For text: .
# []
# For text: .
# []
# For text: remaining
# []
# For text: Mr.
# []
# For text: armed
# []
# For text: were
# []
# For text: 20
# []
# For text: gas
# []
# For text: destroyed
# []
# For text: also
# []
# For text: has
# []
# For text: dealership
# []
# For text: and
# []
# For text: top
# []
# For text: Ta
# []
# For text: EU
# [{'entity': 'B-ORG', 'score': 0.9966484, 'index': 1, 'word': 'EU', 'start': 0, 'end': 2}]
# For text: the
# []
# For text: heavily
# []
# For text: Foreign
# []
# For text: aid
# []
# For text: since
# []
# For text: says
# []
# For text: officials
# []
# For text: missile
# []
# For text: details
# []
# For text: San
# [{'entity': 'B-LOC', 'score': 0.91458416, 'index': 1, 'word': 'San', 'start': 0, 'end': 3}]
# For text: attend
# []
# For text: visit
# []
# For text: past
# []
# For text: Ghazni
# [{'entity': 'B-LOC', 'score': 0.9835471, 'index': 1, 'word': 'G', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.9355113, 'index': 2, 'word': '##ha', 'start': 1, 'end': 3}, {'entity': 'I-LOC', 'score': 0.7172951, 'index': 3, 'word': '##z', 'start': 3, 'end': 4}, {'entity': 'I-LOC', 'score': 0.8424342, 'index': 4, 'word': '##ni', 'start': 4, 'end': 6}]
# For text: Afghanistan
# [{'entity': 'B-LOC', 'score': 0.99980897, 'index': 1, 'word': 'Afghanistan', 'start': 0, 'end': 11}]
# For text: Congress
# [{'entity': 'B-ORG', 'score': 0.999067, 'index': 1, 'word': 'Congress', 'start': 0, 'end': 8}]
# For text: fate
# []
# For text: as
# []
# For text: person
# []
# For text: Mikheil
# [{'entity': 'B-PER', 'score': 0.9980117, 'index': 1, 'word': 'Mi', 'start': 0, 'end': 2}, {'entity': 'B-PER', 'score': 0.9194966, 'index': 2, 'word': '##kh', 'start': 2, 'end': 4}, {'entity': 'B-PER', 'score': 0.94720614, 'index': 3, 'word': '##eil', 'start': 4, 'end': 7}]
# For text: state-run
# []
# For text: does
# []
# For text: worst
# []
# For text: still
# []
# For text: York
# [{'entity': 'B-ORG', 'score': 0.8810849, 'index': 1, 'word': 'York', 'start': 0, 'end': 4}]
# For text: training
# []
# For text: eight
# []
# For text: a
# []
# For text: .
# []
# For text: has
# []
# For text: The
# []
# For text: ,
# []
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: Mr.
# []
# For text: gathered
# []
# For text: prevent
# []
# For text: prime
# []
# For text: of
# []
# For text: the
# []
# For text: scandal
# []
# For text: to
# []
# For text: probe
# []
# For text: of
# []
# For text: planning
# []
# For text: a
# []
# For text: you
# []
# For text: Nations
# []
# For text: federal
# []
# For text: his
# []
# For text: south
# []
# For text: struck
# []
# For text: Mr.
# []
# For text: in
# []
# For text: of
# []
# For text: government
# []
# For text: officials
# []
# For text: town
# []
# For text: President
# []
# For text: fate
# []
# For text: the
# []
# For text: the
# []
# For text: water
# []
# For text: constructive
# []
# For text: a
# []
# For text: which
# []
# For text: is
# []
# For text: to
# []
# For text: to
# []
# For text: the
# []
# For text: for
# []
# For text: lost
# []
# For text: Japanese
# [{'entity': 'B-MISC', 'score': 0.99942774, 'index': 1, 'word': 'Japanese', 'start': 0, 'end': 8}]
# For text: city
# []
# For text: for
# []
# For text: years
# []
# For text: via
# []
# For text: .
# []
# For text: future
# []
# For text: spending
# []
# For text: Union
# [{'entity': 'B-ORG', 'score': 0.9986584, 'index': 1, 'word': 'Union', 'start': 0, 'end': 5}]
# For text: minister
# []
# For text: money
# []
# For text: an
# []
# For text: New
# []
# For text: Paul
# [{'entity': 'B-PER', 'score': 0.99947864, 'index': 1, 'word': 'Paul', 'start': 0, 'end': 4}]
# For text: in
# []
# For text: human
# []
# For text: African
# [{'entity': 'B-MISC', 'score': 0.99932444, 'index': 1, 'word': 'African', 'start': 0, 'end': 7}]
# For text: a
# []
# For text: are
# []
# For text: against
# []
# For text: continue
# []
# For text: in
# []
# For text: resources
# []
# For text: rebel
# []
# For text: on
# []
# For text: The
# []
# For text: forces
# []
# For text: large
# []
# For text: won
# []
# For text: The
# []
# For text: peace
# []
# For text: on
# []
# For text: decided
# []
# For text: .
# []
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: the
# []
# For text: Monday
# []
# For text: hired
# []
# For text: for
# []
# For text: of
# []
# For text: attempting
# []
# For text: fourth
# []
# For text: say
# []
# For text: Hill
# [{'entity': 'B-PER', 'score': 0.77990144, 'index': 1, 'word': 'Hill', 'start': 0, 'end': 4}]
# For text: sign
# []
# For text: mission
# []
# For text: arrived
# []
# For text: saying
# []
# For text: than
# []
# For text: India
# [{'entity': 'B-LOC', 'score': 0.99976546, 'index': 1, 'word': 'India', 'start': 0, 'end': 5}]
# For text: foreclosures
# []
# For text: of
# []
# For text: that
# []
# For text: province
# []
# For text: drug
# []
# For text: in
# []
# For text: its
# []
# For text: watch
# []
# For text: Food
# []
# For text: but
# []
# For text: and
# []
# For text: salaries
# []
# For text: fatwa
# []
# For text: 's
# []
# For text: handed
# []
# For text: the
# []
# For text: camp
# []
# For text: Kurdish
# [{'entity': 'B-MISC', 'score': 0.9990588, 'index': 1, 'word': 'Kurdish', 'start': 0, 'end': 7}]
# For text: President
# []
# For text: implement
# []
# For text: help
# []
# For text: struck
# []
# For text: vow
# []
# For text: as
# []
# For text: quite
# []
# For text: United
# [{'entity': 'B-ORG', 'score': 0.99877137, 'index': 1, 'word': 'United', 'start': 0, 'end': 6}]
# For text: the
# []
# For text: Jalbire
# [{'entity': 'B-ORG', 'score': 0.7551274, 'index': 1, 'word': 'J', 'start': 0, 'end': 1}, {'entity': 'I-ORG', 'score': 0.53626555, 'index': 2, 'word': '##al', 'start': 1, 'end': 3}, {'entity': 'I-ORG', 'score': 0.86483437, 'index': 3, 'word': '##bir', 'start': 3, 'end': 6}]
# For text: of
# []
# For text: groups
# []
# For text: under
# []
# For text: Russian-speaking
# [{'entity': 'B-MISC', 'score': 0.99890363, 'index': 1, 'word': 'Russian', 'start': 0, 'end': 7}]
# For text: is
# []
# For text: Minister
# []
# For text: week
# []
# For text: the
# []
# For text: City
# [{'entity': 'B-LOC', 'score': 0.84165096, 'index': 1, 'word': 'City', 'start': 0, 'end': 4}]
# For text: .
# []
# For text: reasoning
# []
# For text: in
# []
# For text: least
# []
# For text: port
# []
# For text: .
# []
# For text: been
# []
# For text: Mr.
# []
# For text: Diddy
# [{'entity': 'B-PER', 'score': 0.99167305, 'index': 1, 'word': 'Did', 'start': 0, 'end': 3}]
# For text: .
# []
# For text: forces
# []
# For text: Vladimir
# [{'entity': 'B-PER', 'score': 0.9661745, 'index': 1, 'word': 'Vladimir', 'start': 0, 'end': 8}]
# For text: it
# []
# For text: furnish
# []
# For text: news
# []
# For text: addressed
# []
# For text: group
# []
# For text: ,
# []
# For text: offering
# []
# For text: he
# []
# For text: is
# []
# For text: Tuesday
# []
# For text: bodies
# []
# For text: said
# []
# For text: region
# []
# For text: ,
# []
# For text: songs
# []
# For text: Afghanistan
# [{'entity': 'B-LOC', 'score': 0.99980897, 'index': 1, 'word': 'Afghanistan', 'start': 0, 'end': 11}]
# For text: meeting
# []
# For text: in
# []
# For text: discussed
# []
# For text: .
# []
# For text: Boeing
# [{'entity': 'B-ORG', 'score': 0.9988457, 'index': 1, 'word': 'Boeing', 'start': 0, 'end': 6}]
# For text: its
# []
# For text: around
# []
# For text: into
# []
# For text: on
# []
# For text: in
# []
# For text: others
# []
# For text: any
# []
# For text: men
# []
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: .
# []
# For text: Senate
# [{'entity': 'B-ORG', 'score': 0.9981035, 'index': 1, 'word': 'Senate', 'start': 0, 'end': 6}]
# For text: an
# []
# For text: agreed
# []
# For text: and
# []
# For text: Israel
# [{'entity': 'B-LOC', 'score': 0.9998017, 'index': 1, 'word': 'Israel', 'start': 0, 'end': 6}]
# For text: the
# []
# For text: to
# []
# For text: death
# []
# For text: .
# []
# For text: the
# []
# For text: The
# []
# For text: among
# []
# For text: .
# []
# For text: .
# []
# For text: to
# []
# For text: Uzbekistan
# [{'entity': 'B-LOC', 'score': 0.99983966, 'index': 1, 'word': 'Uzbekistan', 'start': 0, 'end': 10}]
# For text: Hollywood
# [{'entity': 'B-LOC', 'score': 0.97051996, 'index': 1, 'word': 'Hollywood', 'start': 0, 'end': 9}]
# For text: country
# []
# For text: .
# []
# For text: and
# []
# For text: crackdown
# []
# For text: ministers
# []
# For text: arms
# []
# For text: to
# []
# For text: .
# []
# For text: first
# []
# For text: southern
# []
# For text: United
# [{'entity': 'B-ORG', 'score': 0.99877137, 'index': 1, 'word': 'United', 'start': 0, 'end': 6}]
# For text: is
# []
# For text: week
# []
# For text: rocket
# []
# For text: President
# []
# For text: to
# []
# For text: Some
# []
# For text: outbreaks
# []
# For text: Energy
# []
# For text: of
# []
# For text: and
# []
# For text: do
# []
# For text: evidence
# []
# For text: said
# []
# For text: embassy
# []
# For text: parliament
# []
# For text: infrastructure
# []
# For text: are
# []
# For text: .
# []
# For text: Turkey
# [{'entity': 'B-LOC', 'score': 0.9998393, 'index': 1, 'word': 'Turkey', 'start': 0, 'end': 6}]
# For text: than
# []
# For text: was
# []
# For text: strike
# []
# For text: of
# []
# For text: outdated
# []
# For text: Authorities
# []
# For text: no
# []
# For text: Beijing
# [{'entity': 'B-LOC', 'score': 0.9996592, 'index': 1, 'word': 'Beijing', 'start': 0, 'end': 7}]
# For text: been
# []
# For text: of
# []
# For text: is
# []
# For text: write-downs
# []
# For text: .
# []
# For text: nearby
# []
# For text: of
# []
# For text: a
# []
# For text: investigated
# []
# For text: by
# []
# For text: President
# []
# For text: injury
# []
# For text: Muslim
# [{'entity': 'B-MISC', 'score': 0.99956065, 'index': 1, 'word': 'Muslim', 'start': 0, 'end': 6}]
# For text: Palestinian
# [{'entity': 'B-MISC', 'score': 0.9990313, 'index': 1, 'word': 'Palestinian', 'start': 0, 'end': 11}]
# For text: allow
# []
# For text: ,
# []
# For text: she
# []
# For text: report
# []
# For text: Security
# []
# For text: .
# []
# For text: charge
# []
# For text: natural
# []
# For text: cope
# []
# For text: Nawaz
# [{'entity': 'B-PER', 'score': 0.997809, 'index': 1, 'word': 'Na', 'start': 0, 'end': 2}, {'entity': 'B-PER', 'score': 0.6177026, 'index': 2, 'word': '##wa', 'start': 2, 'end': 4}, {'entity': 'B-PER', 'score': 0.37125668, 'index': 3, 'word': '##z', 'start': 4, 'end': 5}]
# For text: Friday
# []
# For text: approached
# []
# For text: 1.7
# []
# For text: vote
# []
# For text: ,
# []
# For text: a
# []
# For text: .
# []
# For text: The
# []
# For text: stockpiles
# []
# For text: Prime
# []
# For text: in
# []
# For text: strain
# []
# For text: high-tech
# []
# For text: 27
# []
# For text: killed
# []
# For text: Chinese
# [{'entity': 'B-MISC', 'score': 0.99951303, 'index': 1, 'word': 'Chinese', 'start': 0, 'end': 7}]
# For text: said
# []
# For text: producers
# []
# For text: Jordanian
# [{'entity': 'B-MISC', 'score': 0.99872583, 'index': 1, 'word': 'Jordan', 'start': 0, 'end': 6}, {'entity': 'I-MISC', 'score': 0.94897276, 'index': 2, 'word': '##ian', 'start': 6, 'end': 9}]
# For text: Guangdong
# [{'entity': 'B-ORG', 'score': 0.51260096, 'index': 1, 'word': 'Guangdong', 'start': 0, 'end': 9}]
# For text: to
# []
# For text: plans
# []
# For text: prison
# []
# For text: an
# []
# For text: nuclear-free
# []
# For text: Taliban
# [{'entity': 'B-ORG', 'score': 0.9003508, 'index': 1, 'word': 'Taliban', 'start': 0, 'end': 7}]
# For text: to
# []
# For text: cases
# []
# For text: of
# []
# For text: not
# []
# For text: protectionism
# []
# For text: economy
# []
# For text: a
# []
# For text: election
# []
# For text: of
# []
# For text: minister
# []
# For text: start-up
# []
# For text: of
# []
# For text: in
# []
# For text: Pakistan
# [{'entity': 'B-LOC', 'score': 0.9998098, 'index': 1, 'word': 'Pakistan', 'start': 0, 'end': 8}]
# For text: .
# []
# For text: in
# []
# For text: approval
# []
# For text: performance
# []
# For text: could
# []
# For text: both
# []
# For text: report
# []
# For text: were
# []
# For text: the
# []
# For text: of
# []
# For text: director
# []
# For text: that
# []
# For text: life
# []
# For text: to
# []
# For text: )
# []
# For text: late
# []
# For text: al-Aqsa
# [{'entity': 'B-ORG', 'score': 0.8426094, 'index': 1, 'word': 'al', 'start': 0, 'end': 2}, {'entity': 'I-PER', 'score': 0.49255946, 'index': 3, 'word': 'A', 'start': 3, 'end': 4}, {'entity': 'I-ORG', 'score': 0.6306562, 'index': 4, 'word': '##q', 'start': 4, 'end': 5}, {'entity': 'I-ORG', 'score': 0.54308414, 'index': 5, 'word': '##sa', 'start': 5, 'end': 7}]
# For text: .
# []
# For text: of
# []
# For text: from
# []
# For text: wounded
# []
# For text: In
# []
# For text: of
# []
# For text: smaller
# []
# For text: move
# []
# For text: of
# []
# For text: face
# []
# For text: to
# []
# For text: to
# []
# For text: A
# []
# For text: United
# [{'entity': 'B-ORG', 'score': 0.99877137, 'index': 1, 'word': 'United', 'start': 0, 'end': 6}]
# For text: conflict
# []
# For text: Tuesday
# []
# For text: morning
# []
# For text: in
# []
# For text: non-combat
# []
# For text: are
# []
# For text: he
# []
# For text: .
# []
# For text: the
# []
# For text: that
# []
# For text: Lagos
# [{'entity': 'B-LOC', 'score': 0.9994747, 'index': 1, 'word': 'Lagos', 'start': 0, 'end': 5}]
# For text: heads
# []
# For text: New
# []
# For text: return
# []
# For text: ,
# []
# For text: say
# []
# For text: ,
# []
# For text: weapons
# []
# For text: sensors
# []
# For text: insurgents
# []
# For text: billion
# []
# For text: hare
# []
# For text: out
# []
# For text: kept
# []
# For text: the
# []
# For text: decision
# []
# For text: men
# []
# For text: while
# []
# For text: is
# []
# For text: fleet
# []
# For text: .
# []
# For text: (
# []
# For text: National
# [{'entity': 'B-ORG', 'score': 0.99876046, 'index': 1, 'word': 'National', 'start': 0, 'end': 8}]
# For text: not
# []
# For text: needs
# []
# For text: Parvanov
# [{'entity': 'B-PER', 'score': 0.99921906, 'index': 1, 'word': 'Pa', 'start': 0, 'end': 2}, {'entity': 'B-PER', 'score': 0.6961999, 'index': 2, 'word': '##rva', 'start': 2, 'end': 5}, {'entity': 'B-PER', 'score': 0.4958983, 'index': 3, 'word': '##nov', 'start': 5, 'end': 8}]
# For text: been
# []
# For text: news
# []
# For text: were
# []
# For text: New
# []
# For text: enforce
# []
# For text: the
# []
# For text: séances
# []
# For text: 2008
# []
# For text: 's
# []
# For text: Muslim
# [{'entity': 'B-MISC', 'score': 0.99956065, 'index': 1, 'word': 'Muslim', 'start': 0, 'end': 6}]
# For text: must
# []
# For text: seat
# []
# For text: well
# []
# For text: The
# []
# For text: and
# []
# For text: Kevin
# [{'entity': 'B-PER', 'score': 0.9993994, 'index': 1, 'word': 'Kevin', 'start': 0, 'end': 5}]
# For text: boycotted
# []
# For text: released
# []
# For text: .
# []
# For text: The
# []
# For text: .
# []
# For text: an
# []
# For text: the
# []
# For text: charges
# []
# For text: ,
# []
# For text: .
# []
# For text: U.S.
# [{'entity': 'B-LOC', 'score': 0.99948585, 'index': 1, 'word': 'U', 'start': 0, 'end': 1}, {'entity': 'I-LOC', 'score': 0.99310523, 'index': 2, 'word': '.', 'start': 1, 'end': 2}, {'entity': 'I-LOC', 'score': 0.998569, 'index': 3, 'word': 'S', 'start': 2, 'end': 3}]
# For text: to
# []
# For text: tropical
# [{'entity': 'B-LOC', 'score': 0.44486105, 'index': 1, 'word': 'tropical', 'start': 0, 'end': 8}]
# For text: in
# []
# For text: confirmed
# []
# For text: to
# []
# For text: talks
# []
# For text: Boeing
# [{'entity': 'B-ORG', 'score': 0.9988457, 'index': 1, 'word': 'Boeing', 'start': 0, 'end': 6}]
# For text: The
# []
# For text: World
# [{'entity': 'B-MISC', 'score': 0.56974983, 'index': 1, 'word': 'World', 'start': 0, 'end': 5}]
# For text: a
# []
# For text: tried
# []
# For text: Presidents
# []
# For text: and
# []
# For text: Beijing
# [{'entity': 'B-LOC', 'score': 0.9996592, 'index': 1, 'word': 'Beijing', 'start': 0, 'end': 7}]
# For text: Thursday
# []
# For text: before
# []
# For text: .
# []
# For text: homes
# []
# For text: made
# []
# For text: cord
# []
# For text: .
# []
# For text: during
# []
# For text: the
# []
# For text: Ehud
# [{'entity': 'B-PER', 'score': 0.99830246, 'index': 1, 'word': 'E', 'start': 0, 'end': 1}, {'entity': 'I-PER', 'score': 0.93018526, 'index': 2, 'word': '##hu', 'start': 1, 'end': 3}, {'entity': 'B-PER', 'score': 0.9723399, 'index': 3, 'word': '##d', 'start': 3, 'end': 4}]
# For text: president
# []
# For text: previously
# []
# For text: made
# []
# For text: .
# []
# For text: authorities
# []
# For text: President
# []
# For text: his
# []
# For text: VOA
# [{'entity': 'B-ORG', 'score': 0.9989691, 'index': 1, 'word': 'V', 'start': 0, 'end': 1}, {'entity': 'I-ORG', 'score': 0.9898385, 'index': 2, 'word': '##OA', 'start': 1, 'end': 3}]
# For text: into
# []
# For text: ,
# []
# For text: been
# []
# For text: fighting
# []
# For text: He
# []
# For text: #
# []
# For text: that
# []
# For text: dogs
# []
# For text: was
# []
# For text: metric
# []
# For text: World
# [{'entity': 'B-MISC', 'score': 0.56974983, 'index': 1, 'word': 'World', 'start': 0, 'end': 5}]
# For text: the
# []
# For text: offenses
# []
# For text: pope
# []
# For text: State
# [{'entity': 'B-LOC', 'score': 0.8635722, 'index': 1, 'word': 'State', 'start': 0, 'end': 5}]
# For text: "
# []
# For text: was
# []
# For text: and
# []
# For text: privacy
# []
# For text: leaders
# []
# For text: were
# []
# For text: to
# []
# For text: a
# []
# For text: percent
# []
# For text: ,
# []
# For text: parliamentary
# []
# For text: al-Qaida
# [{'entity': 'B-ORG', 'score': 0.99142164, 'index': 1, 'word': 'al', 'start': 0, 'end': 2}, {'entity': 'I-ORG', 'score': 0.9417501, 'index': 2, 'word': '-', 'start': 2, 'end': 3}, {'entity': 'I-ORG', 'score': 0.9847216, 'index': 3, 'word': 'Q', 'start': 3, 'end': 4}, {'entity': 'I-ORG', 'score': 0.6663551, 'index': 4, 'word': '##aid', 'start': 4, 'end': 7}]
# For text: organization
# []
# For text: in
# []
# For text: energy
# []
# For text: with
# []
# For text: Kathmandu
# [{'entity': 'B-LOC', 'score': 0.99877065, 'index': 1, 'word': 'Kat', 'start': 0, 'end': 3}, {'entity': 'I-LOC', 'score': 0.9906151, 'index': 2, 'word': '##hman', 'start': 3, 'end': 7}, {'entity': 'I-LOC', 'score': 0.99662626, 'index': 3, 'word': '##du', 'start': 7, 'end': 9}]
# For text: Asefi
# [{'entity': 'B-PER', 'score': 0.99707913, 'index': 1, 'word': 'As', 'start': 0, 'end': 2}, {'entity': 'B-PER', 'score': 0.9316341, 'index': 2, 'word': '##ef', 'start': 2, 'end': 4}]
# For text: has
# []
# For text: announced
# []
# For text: elections
# []
# For text: his
# []
# For text: president
# []
# For text: handed
# []
# For text: arrived
# []
# For text: separate
# []
# For text: production
# []
# For text: Ukraine
# [{'entity': 'B-LOC', 'score': 0.99982953, 'index': 1, 'word': 'Ukraine', 'start': 0, 'end': 7}]
# For text: Delp
# [{'entity': 'B-ORG', 'score': 0.9606918, 'index': 1, 'word': 'Del', 'start': 0, 'end': 3}]
# For text: weeks
# []
# For text: Minister
# []
# For text: the
# []
# For text: I
# []
# For text: of
# []
# For text: of
# []
# For text: allow
# []
# For text: king
# []
# For text: Sharon
# [{'entity': 'B-PER', 'score': 0.9977875, 'index': 1, 'word': 'Sharon', 'start': 0, 'end': 6}]
# For text: the
# []
# For text: alleged
# []
# For text: concerns
# []
# For text: of
# []
# For text: world
# []
# For text: recognize
# []
# For text: to
# []
# For text: government
# []
# For text: Associated
# [{'entity': 'B-ORG', 'score': 0.99371475, 'index': 1, 'word': 'Associated', 'start': 0, 'end': 10}]
# For text: group
# []
# For text: .
# []
# For text: .
# []
# For text: (
# []
# For text: called
# []
# For text: ,
# []
# For text: .
# []
# For text: have
# []
# For text: in
# []
# For text: 's
# []
# For text: President
# []
# For text: home
# []
# For text: president
# []
# For text: the
# []
# For text: services
# []
# For text: agency
# []
# For text: military
# []
# For text: those
# []
# For text: effort
# []
# For text: The
# []
# For text: 2005
# []
# For text: of
# []
# For text: week
# []
# For text: Straw
# [{'entity': 'B-PER', 'score': 0.9840851, 'index': 1, 'word': 'St', 'start': 0, 'end': 2}]
# For text: the
# []
# For text: reported
# []
# For text: to
# []
# For text: federal
# []
# For text: Musab
# [{'entity': 'B-PER', 'score': 0.9915826, 'index': 1, 'word': 'Musa', 'start': 0, 'end': 4}]
# For text: pipeline
# []
# For text: historic
# []
# For text: ,
# []
# For text: the
# []
# For text: Japan
# [{'entity': 'B-LOC', 'score': 0.9998441, 'index': 1, 'word': 'Japan', 'start': 0, 'end': 5}]
# For text: killed
# []
# For text: Bush
# [{'entity': 'B-PER', 'score': 0.99541485, 'index': 1, 'word': 'Bush', 'start': 0, 'end': 4}]
# For text: why
# []
# For text: and
# []
# For text: expected
# []
# For text: and
# []
# For text: been
# []
# For text: Bertel
# [{'entity': 'B-PER', 'score': 0.998588, 'index': 1, 'word': 'Bert', 'start': 0, 'end': 4}, {'entity': 'B-PER', 'score': 0.6062748, 'index': 2, 'word': '##el', 'start': 4, 'end': 6}]
# For text: a
# []
# For text: Saturday
# []
# For text: soldiers
# []
# For text: country
# []
# For text: Aceh
# [{'entity': 'B-LOC', 'score': 0.9843492, 'index': 1, 'word': 'Ace', 'start': 0, 'end': 3}, {'entity': 'I-LOC', 'score': 0.9892609, 'index': 2, 'word': '##h', 'start': 3, 'end': 4}]
# For text: Hebei
# [{'entity': 'B-ORG', 'score': 0.73944163, 'index': 1, 'word': 'He', 'start': 0, 'end': 2}, {'entity': 'I-ORG', 'score': 0.7158986, 'index': 2, 'word': '##bei', 'start': 2, 'end': 5}]
# For text: warlords
# []
# For text: Security
# []
# For text: the
# []
# For text: from
# []
# For text: Katsav
# [{'entity': 'B-ORG', 'score': 0.9910088, 'index': 1, 'word': 'Kat', 'start': 0, 'end': 3}, {'entity': 'I-ORG', 'score': 0.98424244, 'index': 2, 'word': '##sa', 'start': 3, 'end': 5}, {'entity': 'I-ORG', 'score': 0.848094, 'index': 3, 'word': '##v', 'start': 5, 'end': 6}]
# For text: passengers
# []
# For text: the
# []
# For text: been
# []
# For text: 538
# []
# For text: ministers
# []
# For text: compared
# []
# For text: the
# []
# For text: by
# []
# For text: attempted
# []
# For text: Iraq
# [{'entity': 'B-LOC', 'score': 0.99984574, 'index': 1, 'word': 'Iraq', 'start': 0, 'end': 4}]
# For text: ,
# []
# For text: ,
# []
# For text: grenades
# []
# For text: Members
# []
# For text: administration
# []
# For text: de
# []
# For text: Zia
# [{'entity': 'B-PER', 'score': 0.93393576, 'index': 1, 'word': 'Z', 'start': 0, 'end': 1}]
# For text: aimed
# []
# For text: to
# []
# For text: is
# []
# For text: forces
# []
# For text: named
# []
# For text: any
# []
# For text: .
# []
# For text: Islamabad
# [{'entity': 'B-LOC', 'score': 0.99950635, 'index': 1, 'word': 'Islam', 'start': 0, 'end': 5}, {'entity': 'I-LOC', 'score': 0.99883324, 'index': 2, 'word': '##abad', 'start': 5, 'end': 9}]
# For text: records
# []
# For text: state
# []
# For text: ,
# []
# For text: the
# []
# For text: The
# []
# For text: designated
# []
# For text: Plassnik
# [{'entity': 'B-ORG', 'score': 0.9857022, 'index': 1, 'word': 'P', 'start': 0, 'end': 1}, {'entity': 'I-ORG', 'score': 0.7748566, 'index': 2, 'word': '##lass', 'start': 1, 'end': 5}, {'entity': 'I-ORG', 'score': 0.92712975, 'index': 3, 'word': '##nik', 'start': 5, 'end': 8}]
# For text: currency
# []
# For text: others
# []
# For text: similar
# []
# For text: cuts
# []
# For text: destabilize
# []
# For text: own
# []
# For text: out
# []
# For text: intends
# []
# For text: of
# []
# For text: "
# []
# For text: five
# []
# For text: A
# []
